# %%
import numpy as np
import pandas as pd

grundy_astrometry = pd.read_csv('data_dump_astrometry_2020-09-26.csv')
grundy_orbit_props = pd.read_csv('grundy_orbit_props_9.26.2020.csv')

print(grundy_astrometry)
print(grundy_orbit_props)

johnston_tnos = pd.read_csv('johnston_tnos.csv',sep='\t')
# Out:
#      number  designation         epoch   delta_AU   RA_hours   DEC_deg  \
# 0     26308   1998 SM165  2.452266e+06   34.83040   0.975961   2.87706
# 1     26308   1998 SM165  2.452272e+06   34.93584   0.975814   2.87836
# 2     26308   1998 SM165  2.452821e+06   35.76803   1.355792   4.57038
# 3     26308   1998 SM165  2.452830e+06   35.62429   1.361222   4.57497
# 4     26308   1998 SM165  2.452846e+06   35.37240   1.365092   4.54852
# ..      ...          ...           ...        ...        ...       ...
# 876       0   2015 RB280  2.458765e+06   41.07006   0.939242   6.28869
# 877       0   2015 RP280  2.458763e+06   44.38431   0.674842   6.87370
# 878       0   2015 RT245  2.458729e+06   41.27709   0.700628   5.21351
# 879       0   2015 VM173  2.458699e+06   45.75952   3.555664  17.25927
# 880       0   2015 VW168  2.458779e+06   42.44277   3.457917  17.41612
#
#          dRA   dRA_err     dDEC   dDEC_err
# 0   -0.18912   0.00315  0.10161    0.00100
# ...
