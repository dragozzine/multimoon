# %%
import rebound


sim = rebound.Simulation()
sim.add(m=.86)

sim.add(P = .013108)
sim.add(P = .045522)
sim.add(P = .048479)
sim.add(P = .163245)

sim.status()
rebound.OrbitPlot(sim)
# Out:
# ---------------------------------
# REBOUND version:     	3.12.2
# REBOUND built on:    	Sep 17 2020 16:26:03
# Number of particles: 	5
# Selected integrator: 	ias15
# Simulation time:     	0.0000000000000000e+00
# Current timestep:    	0.001000
# ---------------------------------
# <rebound.Particle object, m=0.86 x=0.0 y=0.0 z=0.0 vx=0.0 vy=0.0 vz=0.0>
# <rebound.Particle object, m=0.0 x=0.015526391281615969 y=0.0 z=0.0 vx=0.0 vy=7.442416354453056 vz=0.0>
# <rebound.Particle object, m=0.0 x=0.03560632305053565 y=0.0 z=0.0 vx=0.0 vy=4.914571544172386 vz=0.0>
# <rebound.Particle object, m=0.0 x=0.03713202835384548 y=0.0 z=0.0 vx=0.0 vy=4.812545947289705 vz=0.0>
# <rebound.Particle object, m=0.0 x=0.0834205080225269 y=0.0 z=0.0 vx=0.0 vy=3.2107967185800343 vz=0.0>
# ---------------------------------
# (<Figure size 360x360 with 1 Axes>, <AxesSubplot:xlabel='x', ylabel='y'>)
