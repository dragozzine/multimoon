# %%
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import corner
import numpy as np
import pandas as pd
import emcee
import sys
import os
import mm_likelihood
from astropy.time import Time
import commentjson as json
import mm_param
import mm_make_geo_pos
from mm_SPINNY.spinny_plots import spinny_plot
from mm_SPINNY.spinny_generate import *
from mm_SPINNY.spinny_vector import *
from mm_SPINNY.spinny_nosun import *
from mm_SPINNY.mm_vpython import *
from mm_SPINNY.keplerian import *

import matplotlib.animation as animation


def update(data):
    points.set_ydata(data)
    return points

class ReadJson(object):
    def __init__(self, filename):
        print('Read the runprops.txt file')
        self.data = json.load(open(filename))
    def outProps(self):
        return self.data
import glob,os

def create(objname,filename):
    if 'results' in filename:
        #os.chdir(filename)
        getData = ReadJson('runprops.txt')
#else:
        #getData = ReadJson('most_recent_runprops.txt')
        runprops = getData.outProps()
        objname = runprops.get("objectname")

    #if not 'results' in os.getcwd():
    #    os.chdir('../../../results/'+objname+'/')
    #    results = max(glob.glob(os.path.join(os.getcwd(), '*/')), key=os.path.getmtime)
    #    os.chdir(results)

    backend = emcee.backends.HDFBackend('chain.h5')

    init = pd.read_csv(objname+'_init_guess.csv',index_col=0)
    print(init)
    
    
    best_llhoods = pd.read_csv('best_likelihoods.csv')
    best = best_llhoods.iloc[-(1)]
    ind = ['mass_1','mass_2','sma_2','ecc_2','aop_2','inc_2','lan_2','mea_2','mass_3','sma_3','ecc_3','aop_3','inc_3','lan_3','mea_3']
    cols = ['mean','stddev']
    best_init = pd.DataFrame(columns = cols, index = ind)
    best_init['mean']['mass_1'] = best['mass_1']
    best_init['mean']['mass_2'] = best['mass_2']
    best_init['mean']['sma_2'] = best['sma_2']
    best_init['mean']['ecc_2'] = best['ecc_2']
    best_init['mean']['aop_2'] = best['aop_2']
    best_init['mean']['inc_2'] = best['inc_2']
    best_init['mean']['lan_2'] = best['lan_2']
    best_init['mean']['mea_2'] = best['mea_2']
    best_init['mean']['mass_3'] = best['mass_3']
    best_init['mean']['sma_3'] = best['sma_3']
    best_init['mean']['ecc_3'] = best['ecc_3']
    best_init['mean']['aop_3'] = best['aop_3']
    best_init['mean']['inc_3'] = best['inc_3']
    best_init['mean']['lan_3'] = best['lan_3']
    best_init['mean']['mea_3'] = best['mea_3']
 
    best_init['stddev']['mass_1'] = init['stddev']['mass_1']
    best_init['stddev']['mass_2'] = init['stddev']['mass_2']
    best_init['stddev']['sma_2'] = init['stddev']['sma_2']
    best_init['stddev']['ecc_2'] = init['stddev']['ecc_2']
    best_init['stddev']['aop_2'] = init['stddev']['aop_2']
    best_init['stddev']['inc_2'] = init['stddev']['inc_2']
    best_init['stddev']['lan_2'] = init['stddev']['lan_2']
    best_init['stddev']['mea_2'] = init['stddev']['mea_2']
    best_init['stddev']['mass_3'] = init['stddev']['mass_3']
    best_init['stddev']['sma_3'] = init['stddev']['sma_3']
    best_init['stddev']['ecc_3'] = init['stddev']['ecc_3']
    best_init['stddev']['aop_3'] = init['stddev']['aop_3']
    best_init['stddev']['inc_3'] = init['stddev']['inc_3']
    best_init['stddev']['lan_3'] = init['stddev']['lan_3']
    best_init['stddev']['mea_3'] = init['stddev']['mea_3']
    print(runprops)
    runs_dir = runprops.get('objectname')
    best_init.to_csv(runs_dir+'_init_guess_from_best.csv')
    print(best_init)

# %%
create('Eris','../results/Eris/000_6/')
# Out:
# Read the runprops.txt file
#                 mean        stddev
# mass_1  1.530000e+22  1.000000e+19
# mass_2  9.600000e+20  1.000000e+18
# sma_2   1.246800e+04  5.000000e+02
# ecc_2   0.000000e+00  1.000000e-03
# aop_2   0.000000e+00  5.000000e+00
# inc_2   6.125000e+01  1.000000e+00
# lan_2   1.392000e+02  1.000000e+00
# mea_2   1.557500e+02  1.000000e+01
# mass_3  6.120000e+19  1.000000e+18
# sma_3   3.740800e+04  1.000000e+02
# ecc_3   2.500000e-03  1.000000e-03
# aop_3   3.050000e+02  5.000000e+00
# inc_3   6.190000e+01  1.800000e-01
# lan_3   1.390000e+02  2.150000e-01
# mea_3   3.609000e+01  1.000000e+01
# {'first_run': False, 'date': '2021-08-20_15.50.57', 'time': 'now', 'user': 'autogenerate', 'MultiMoon commit hash': 'autogenerate', 'mm_initguess_which': 'get_init_guess_from_dist', 'RunGoal': 'Fit Eris', 'lockspinanglesflag': False, 'transform': True, 'com_offset': False, 'min_periapse': 8000, 'mhill_sphere_reject': 3.5, 'objectname': 'Eris', 'obs_df': 'Eris_obs_df_w_Herc.csv', 'run_file': '000', 'numobjects': 3, 'dynamicstoincludeflags': '000', 'includesun': 0, 'nwalkers': 960, 'nburnin': 30000, 'nsteps': 30000, 'essgoal': 10, 'maxiter': 1, 'nthinning': 100, 'op_mode': False, 'thin_run': True, 'thin_plots': 10, 'maxreset': 200, 'spinny_tolerance': 1e-10, 'numprocesses': 30, 'epoch_SJD': 2453979.0, 'verbose': False, 'updatebestfitfile': True, 'use_clustering': True, 'clustering_burnin': 30000, 'clustering_maxfrac': 0.8, 'is_mcmc': True, 'get_resid': False, 'startfromfile': False, 'names_dict': {'name_1': 'Eris', 'name_2': 'Hercules', 'name_3': 'Dysnomia'}, 'axes_size': {'obj_1': 1163, 'obj_2': 450, 'obj_3': 350}, 'albedos': {'obj_1': 0.96, 'obj_2': 0.04, 'obj_3': 0.04}, 'float_dict': {'mass_1': 1, 'mass_2': 1, 'sma_2': 1, 'ecc_2': 1, 'aop_2': 1, 'inc_2': 1, 'lan_2': 1, 'mea_2': 1, 'mass_3': 1, 'sma_3': 1, 'ecc_3': 1, 'aop_3': 1, 'inc_3': 1, 'lan_3': 1, 'mea_3': 1, 'j2r2_1': 0, 'spinc_1': 0, 'sprate_1': 0, 'spaop_1': 0, 'splan_1': 0, 'c22r2_1': 0, 'lat_offset': 0, 'long_offset': 0}, 'chain_file': None, 'runs_file': '../runs/Eris/000', 'results_folder': '../results/Eris/Eris_2021-08-20_15.50.57_000', 'init_filename': '../runs/Eris/000/Eris_init_guess.csv', 'obsdata_file': '../runs/Eris/000/../observations/Eris_obs_df_w_Herc.csv', 'priors_filename': '../runs/Eris/000/Eris_priors_df.csv', 'float_names': ['mass_1', 'mass_2', 'sma_2', 'ecc_2', 'aop_2', 'inc_2', 'lan_2', 'mea_2', 'mass_3', 'sma_3', 'ecc_3', 'aop_3', 'inc_3', 'lan_3', 'mea_3'], 'total_df_names': [['mass_1'], ['mass_2'], ['sma_2'], ['ecc_2'], ['aop_2'], ['inc_2'], ['lan_2'], ['mea_2'], ['mass_3'], ['sma_3'], ['ecc_3'], ['aop_3'], ['inc_3'], ['lan_3'], ['mea_3']]}
#                mean stddev
# mass_1  1.53778e+22  1e+19
# mass_2  7.89233e+20  1e+18
# sma_2       12420.1    500
# ecc_2     0.0229433  0.001
# aop_2       130.111      5
# inc_2       62.1647      1
# lan_2       138.902      1
# mea_2       5.27648     10
# mass_3   6.9109e+19  1e+18
# sma_3         37282    100
# ecc_3    0.00488574  0.001
# aop_3        299.07      5
# inc_3       62.6136   0.18
# lan_3        137.92  0.215
# mea_3        39.316     10
